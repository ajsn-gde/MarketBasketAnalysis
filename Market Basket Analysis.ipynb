# %% [markdown]
# ## Library

# %%
# !pip install -U ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 44.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 67.5 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=617f3014e3e5ae4ecef9efcc6d95abe11a4373dcb8ab719c8ccdf9532f91f374
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...

# %%
import pandas as pd
from scipy import stats
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules

import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport
from IPython.display import display, HTML
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Data

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Science/Dataset/Retail Data.csv', header=0)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
profile_df = ProfileReport(df, title='Profiling Report of Online Retail Data', explorative=True)

profile_df.to_file("profile_report.html")
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/htmlmin/main.py:28: DeprecationWarning: 'cgi' is deprecated and slated for removal in Python 3.13
#   import cgi
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
display(HTML("profile_report.html"))

# %%
df[df.duplicated() == True].count()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# order_id        6479
# product_code    6479
# product_name    6479
# quantity        6479
# order_date      6479
# price           6479
# customer_id     6411
# dtype: int64

# %%
df.isnull().any()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# order_id        False
# product_code    False
# product_name     True
# quantity        False
# order_date      False
# price           False
# customer_id      True
# dtype: bool

# %%
df.info()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461773 entries, 0 to 461772
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      461773 non-null  object
#  1   product_code  461773 non-null  object
#  2   product_name  459055 non-null  object
#  3   quantity      461773 non-null  int64
#  4   order_date    461773 non-null  object
#  5   price         461773 non-null  float64
#  6   customer_id   360853 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 24.7+ MB

# %%
df.describe()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             quantity          price    customer_id
# count  461773.000000  461773.000000  360853.000000
# mean        9.088892       4.569963   15557.611138
# std        86.366467     153.411566    1593.728741
# min     -9600.000000  -53594.360000   12346.000000
# 25%         1.000000       1.250000   14210.000000
# 50%         3.000000       2.100000   15580.000000
# 75%        10.000000       4.210000   16938.000000
# max     10200.000000   25111.090000   18287.000000

# %%
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   order_id product_code                     product_name  quantity  \
# 0   493410      TEST001          This is a test product.         5
# 1  C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2   493412      TEST001          This is a test product.         5
# 3   493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4   493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
#
#             order_date  price  customer_id
# 0  2010-01-04 09:24:00   4.50      12346.0
# 1  2010-01-04 09:43:00   4.25      14590.0
# 2  2010-01-04 09:53:00   4.50      12346.0
# ...

# %%
for column in df.columns:
    print(f"Unique values in column '{column}':")
    print(df[column].unique())
    print()
# Out:
# Unique values in column 'order_id':
# ['493410' 'C493411' '493412' ... '539990' '539991' '539992']
#
# Unique values in column 'product_code':
# ['TEST001' '21539' '21724' ... '22721' '22970' '22971']
#
# Unique values in column 'product_name':
# ['This is a test product.' 'RETRO SPOTS BUTTER DISH'
#  'PANDA AND BUNNIES STICKER SHEET' ... '*USB Office Mirror Ball'
#  'MINI LADLE LOVE HEART PINK' 'MINI LADLE LOVE HEART RED']
#
# Unique values in column 'quantity':
# [    5    -1     1    36    12     2    24    -3     4     6    10     3
#     -2    -4    20    32     8     7    30    48   288    96    18    72
#    200    23    25    11   240   252   480   468   144    64   120    60
#      9   -24   -84    89   300   100    50  -104  -450    40   408    13
#     16   -43   -36    14    17   -18  -200   150    15   192  1440  1080
#     80   576   600   832    -8    -6 -2127   -12   -95    -7    -9  -260
#     -5    19   -17   432    90    27    43   256    65   180   720    28
# ...

# %% [markdown]
# Kesimpulan :
# 1. Terdapat baris yang duplikat
# 2. Terdapat 2 kolom yang memiliki nilai null atau missing values, yakni product_name dan customer_id
# 3. Kolom customer_id masih memiliki tipe numerik(float64) dan kolom order_date juga memiliki tipe data yang bukan datetime
# 4. Pada kolom numerik, ada yang janggal, yakni quantity dan price yang memiliki nilai negatif padahal harusnya penjualan tidak ada yang negatif dan setelah ditelusuri baris pada kolom quantity dan price yang memiliki nilai negatif, memiliki format order id yang berbeda dengan kebanyakan baris data lainnya, yakni menggunakan awalan 'C' dimana bisa menandakan transaksi tersebut dicancel atau dibatalkan.
# 5. Lalu, saat melihat 5 data teratas ditemukan bahwa ada produk tester yang turut dimasukkan kepada dataset dimana untuk sekarang data tersebut tidak diperlukan karena kita ingin menganalisis asosiasi dari produk-produk yang bukan tester yang dijual

# %% [markdown]
# ## Data Preprocessing

# %%
df_clean = df.copy()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# menghapus baris yang memiliki nilai missing values pada kolom product_name dan customer_id
df_clean.dropna(subset=['product_name', 'customer_id'], inplace=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#menghapus baris yang memiliki nilai negatif pada quantity dan price
df_clean = df_clean[(df_clean['quantity'] > 0) & (df_clean['price'] > 0)]
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#menghapus baris yang order idnya diawali dengna huruf c
df_clean = df_clean[~(df_clean['order_id'].str[:1] == 'C')]
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#menghapus data tester menggunakan product_code
df_clean = df_clean[~(df_clean['product_code'].str.lower().str.contains('test'))]
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#mengubah tipe data kolom customer_id dan order_date
df_clean['customer_id'] = df_clean['customer_id'].astype(str)
df_clean['order_date'] = pd.to_datetime(df_clean['order_date'])
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_clean['amount'] = df_clean['quantity'] * df_clean['price']
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#mengganti product name menjadi seragam dari salah satu product name yang sering muncul
# grouping product_code dan product_name lalu menambahkan fungsi agregat, yakni nunique yang diberlakukan ke kolom order_id dan hasilnya dimasukkan ke new column, yakni order_cnt
# sorting nilai berdasarkan product code terlebih dahulu dari terkecil ke terbesar, baru diurutkan melalu order_cnt dari terbesar ke terkecil
most_freq_product_name = df_clean.groupby(['product_code', 'product_name'], as_index = False).agg(order_cnt=('order_id', 'nunique')).sort_values(['product_code','order_cnt'], ascending=[True,False])

#lalu buatkan rank dari product_name dalam satu grup(product_code) yang memiliki order_cnt terbanyak
most_freq_product_name['rank'] = most_freq_product_name.groupby('product_code')['order_cnt'].rank(method='first', ascending=False)

#filter isi most_freq_product_name hingga hanya terdiri dari product_name yang memiliki order_cnt terbanyak
most_freq_product_name = most_freq_product_name[most_freq_product_name['rank'] == 1].drop(columns=['order_cnt', 'rank'])

#lakukan merge pada df_clean dengan most_freq_product_name dimana kolom product_name pada most_freq_product_name di rename terlebih dahulu
#lakukan merge secara left di mana menyesuaikan dengan product code di df_clean
df_clean = df_clean.merge(most_freq_product_name.rename(columns={'product_name':'most_freq_product_name'}), how='left', on='product_code')

#ganti nama produk dengan most_freq_product_name
df_clean['product_name'] = df_clean['most_freq_product_name'].str.lower()

df_clean = df_clean.drop(columns='most_freq_product_name')
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
most_freq_product_name
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      product_code                product_name
# 0           10002  INFLATABLE POLITICAL GLOBE
# 1           10080    GROOVY CACTUS INFLATABLE
# 2           10120                DOGGY RUBBER
# 3          10123C        HEARTS WRAPPING TAPE
# 4          10123G     ARMY CAMO WRAPPING TAPE
# ...           ...                         ...
# 4287            D                    Discount
# 4288            M                      Manual
# 4289         PADS  PADS TO MATCH ALL CUSHIONS
# 4290         POST                     POSTAGE
# 4291       SP1002      KID'S CHALKBOARD/EASEL
#
# [3880 rows x 2 columns]

# %%
df_clean
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        order_id product_code                       product_name  quantity  \
# 0        493414        21844                  red retrospot mug        36
# 1        493414        21533          retro spot large milk jug        12
# 2        493414        37508    new england ceramic cake server         2
# 3        493414       35001G               hand open shape gold         2
# 4        493414        21527   red retrospot traditional teapot        12
# ...         ...          ...                                ...       ...
# 352887   539988        84380  set of 3 butterfly cookie cutters         1
# ...

# %%
#menghapus outlier
df_clean = df_clean[(np.abs(stats.zscore(df_clean[['quantity','amount']]))<3).all(axis=1)]
df_clean = df_clean.reset_index(drop=True)
df_clean
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        order_id product_code                       product_name  quantity  \
# 0        493414        21844                  red retrospot mug        36
# 1        493414        21533          retro spot large milk jug        12
# 2        493414        37508    new england ceramic cake server         2
# 3        493414       35001G               hand open shape gold         2
# 4        493414        21527   red retrospot traditional teapot        12
# ...         ...          ...                                ...       ...
# 350087   539988        84380  set of 3 butterfly cookie cutters         1
# ...

# %% [markdown]
# ## Menyiapkan data basket

# %%
basket = pd.pivot_table(df_clean,index='order_id', columns='product_name', values='product_code', aggfunc='nunique', fill_value=0)
basket
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                             0                                  0
# 493427                             0                                  0
# 493428                             0                                  0
# 493432                             0                                  0
# 493433                             0                                  0
# ...                              ...                                ...
# 539981                             0                                  0
# ...

# %%
def encode(x):
  if x == 0:
    return False
  else :
    return True

basket_encode = basket.applymap(encode)
basket_encode
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-24-39e04c107c5e>:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_encode = basket.applymap(encode)
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                         False                              False
# 493427                         False                              False
# 493428                         False                              False
# 493432                         False                              False
# 493433                         False                              False
# ...

# %%
#filter sehingga minimal terdapat 2 barang yang terbeli dalam suatu order
basket_filter = basket_encode[(basket_encode>0).sum(axis=1)>1]
basket_filter
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                         False                              False
# 493427                         False                              False
# 493428                         False                              False
# 493432                         False                              False
# 493433                         False                              False
# ...                              ...                                ...
# 539978                         False                              False
# ...

# %%
basket_filter.info()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# Index: 15004 entries, 493414 to 539988
# Columns: 3842 entries, 10 colour spaceboy pen to zinc willie winkie  candle stick
# dtypes: bool(3842)
# memory usage: 55.1+ MB

# %% [markdown]
# # Implementing Algorithm

# %%
frequent_itemset = apriori(basket_filter, min_support=0.01, use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)
frequent_itemset['product_cnt']=frequent_itemset['itemsets'].apply(lambda x : len(x))
frequent_itemset
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        support                                           itemsets  product_cnt
# 0     0.177953               (white hanging heart t-light holder)            1
# 1     0.099440                         (regency cakestand 3 tier)            1
# 2     0.096841                          (jumbo bag red retrospot)            1
# 3     0.079912                 (pack of 72 retro spot cake cases)            1
# 4     0.078512                    (assorted colour bird ornament)            1
# ...        ...                                                ...          ...
# ...

# %%
#hitung confidence, lift, support
product_association = association_rules(frequent_itemset,
                                        metric='confidence',
                                        min_threshold=0.7,
                                        num_itemsets=None).sort_values(['support', 'confidence'], ascending=[False, False]).reset_index(drop=True)

product_association
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                           antecedents  \
# 0                  (red hanging heart t-light holder)
# 1                    (sweetheart ceramic trinket box)
# 2                                 (toilet metal sign)
# 3                      (red retrospot sugar jam bowl)
# 4                      (painted metal pears assorted)
# ..                                                ...
# 81  (green 3 piece mini dots cutlery set, blue 3 p...
# 82  (green 3 piece mini dots cutlery set, pink 3 p...
# 83     (key fob , front  door , key fob , back door )
# 84  (poppy's playhouse livingroom, poppy's playhou...
# ...

# %% [markdown]
# Kesimpulan
#
# ---
# 1. Red Hanging Heart T-Light Order paling sering dibeli bersamaan dengan White Hanging Heart T-Light Order dan umumnya orang akan membeli White Hanging Heart T-Light Order setelah Red Hanging Heart T-Light Order. Akan tetapi, dari 5 asosiasi produk teratas berdasarkan nilai support confidence, asosiasi produk ini memiliki nilai lift terkecil yang berarti kedua produk ini juga cukup sering dibeli secara terpisah.
#
# 2. Dari 5 produk dengan support dan confidence tertinggi, ada 2 produk yang memiliki nilai lift cukup tinggi ketimbang produk lainnya seperti toilet metal sign dan bathroom metal sign dan juga red retrospot sugar jam bowl bersamaan dengan red retrospot milk jug sehingga dapat dikatakan bahwa produk yang memiliki kesamaan memiliki peluang tinggi untuk dibeli bersamaan ketimbang terpisah.
